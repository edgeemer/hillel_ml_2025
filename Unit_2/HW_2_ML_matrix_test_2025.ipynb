# %% [markdown]
# <a href="https://colab.research.google.com/github/edgeemer/hillel_ml_2025/blob/main/Unit_2/HW_2_ML_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Тест 1. множення матриць (на парері)
#
# пройдіть матеріал та тест за лінкою:
#
# https://www.khanacademy.org/math/precalculus/x9e81a4f98389efdf:matrices/x9e81a4f98389efdf:multiplying-matrices-by-matrices/e/multiplying_a_matrix_by_a_matrix

# %% [markdown]
# ![Screenshot 2025-01-17 211953.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
